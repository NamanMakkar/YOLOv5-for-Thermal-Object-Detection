# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/NamanMakkar/YOLOv5-for-Thermal-Object-Detection  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks

# %%
# !python train.py --img 1280 --cfg yolov5x6-ms.yaml --hyp hyp.scratch.yaml --batch 3 --epochs 4 --data data-three-label.yaml --weights yolov5x6.pt --workers 24 --name yolo_flir_det

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# !python detect.py --source /kaggle/working/datasets/flir-three-labels/images/test --weights runs/train/yolo_flir_det/weights/best.pt --conf 0.25 --name yolo_flir_det

# %%
import os
import numpy as np
from PIL import Image
import random
detection_dir = 'runs/detect/yolo_flir_det'
import matplotlib.pyplot as plt 

detection_images = [os.path.join(detection_dir,x) for x in os.listdir(detection_dir)]

random_detection_image = Image.open(random.choice(detection_images))
plt.imshow(np.array(random_detection_image))

# %%
# !python val.py --weights runs/train/yolo_flir_det/weights/best.pt --data data-three-label.yaml --img 1280 --iou 0.5 --task test --name yolo_flir_det
